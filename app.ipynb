# %% [markdown]
# # Import Libraries

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (3.10.8)
# Requirement already satisfied: seaborn in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\prava\anaconda3\envs\benefitbot\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
schemes_df = pd.read_csv("ap_schemes.csv")
schemes_df.columns = schemes_df.columns.str.strip().str.lower()

scholarships_df = pd.read_csv("ap_scholarships.csv")
scholarships_df.columns = scholarships_df.columns.str.strip().str.lower()

# %% [markdown]
# # Loading Schemes Dataset

# %%
schemes = pd.read_csv("ap_schemes.csv")
schemes.head()
# Out:
#                             scheme_name         eligible_caste       gender  \
# 0          Talliki Vandanam (Amma Vodi)   OC,BC,SC,ST,Minority  Male,Female
# 1                    Dr NTR Vaidya Seva   OC,BC,SC,ST,Minority  Male,Female
# 2            Annadata Sukhibhava Scheme   OC,BC,SC,ST,Minority  Male,Female
# 3  AP Housing (Mana illu Mana gouravam)  OBC,SC,ST,BC,Minority       Female
# 4   NTR Bharosa Pension Scheme (Senior)   OC,BC,SC,ST,Minority  Male,Female
#
#                      education occupation  min_age  max_age  max_income  \
# 0  School,Intermediate,Diploma    Student        6       18      144000
# 1                          ALL        ALL        1      120      500000
# 2                          ALL     Farmer       18      120       20000
# 3                          ALL     Worker       18      120      300000
# 4                         NONE     Senior       60      120       20000
#
#                               apply_link
# 0            https://navasakam.ap.gov.in
# 1      https://drntrvaidyaseva.ap.gov.in
# 2  https://annadathasukhibhava.ap.gov.in
# 3              https://housing.ap.gov.in
# 4           https://sspensions.ap.gov.in

# %%
scholarships = pd.read_csv("ap_scholarships.csv")
scholarships.head()
# Out:
#                                     scholarship_name        eligible_caste  \
# 0  Post Matric Scholarship – Tuition Fee (Jnanabh...  OC,BC,SC,ST,Minority
# 1  Post Matric Scholarship – Maintenance Fee (Jna...  OC,BC,SC,ST,Minority
# 2                             Pre Matric Scholarship    OBC,SC,ST,Minority
# 3                               Minority Scholarship              Minority
# 4                          AICTE Pragati Scholarship             OBC,SC,ST
#
#         gender          education occupation  min_age  max_age  max_income  \
# 0  Male,Female       BTech,Degree    Student       18       22      120000
# 1  Male,Female       BTech,Degree    Student       18       22      120000
# 2  Male,Female             School    Student        6       16      200000
# 3  Male,Female             Degree    Student       18      120      250000
# 4       Female  B.E,BTech,Diploma    Student       18       22      800000
#
#    min_marks                                         apply_link
# 0         75                       https://jnanabhumi.ap.gov.in
# 1         75                       https://jnanabhumi.ap.gov.in
# 2         40                       https://jnanabhumi.ap.gov.in
# 3         50                        https://scholarships.gov.in
# 4         60  https://www.aicte-india.org/schemes/students-d...

# %%
print("Schemes Info")
schemes.info()
# Out:
# Schemes Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   scheme_name     9 non-null      object
#  1   eligible_caste  9 non-null      object
#  2   gender          9 non-null      object
#  3   education       9 non-null      object
#  4   occupation      9 non-null      object
#  5   min_age         9 non-null      int64
#  6   max_age         9 non-null      int64
#  7   max_income      9 non-null      int64
#  8   apply_link      9 non-null      object
# dtypes: int64(3), object(6)
# memory usage: 776.0+ bytes

# %%
print("\nScholarships Info")
scholarships.info()
# Out:
# Scholarships Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   scholarship_name  7 non-null      object
#  1   eligible_caste    7 non-null      object
#  2   gender            7 non-null      object
#  3   education         7 non-null      object
#  4   occupation        7 non-null      object
#  5   min_age           7 non-null      int64
#  6   max_age           7 non-null      int64
#  7   max_income        7 non-null      int64
#  8   min_marks         7 non-null      int64
#  9   apply_link        7 non-null      object
# dtypes: int64(4), object(6)
# memory usage: 688.0+ bytes

# %% [markdown]
# # Checking missing values

# %%
print(schemes.isnull().sum())
# Out:
# scheme_name       0
# eligible_caste    0
# gender            0
# education         0
# occupation        0
# min_age           0
# max_age           0
# max_income        0
# apply_link        0
# dtype: int64

# %%
print(scholarships.isnull().sum())
# Out:
# scholarship_name    0
# eligible_caste      0
# gender              0
# education           0
# occupation          0
# min_age             0
# max_age             0
# max_income          0
# min_marks           0
# apply_link          0
# dtype: int64

# %% [markdown]
# # AP Schemes

# %% [markdown]
# # Expand Schemes Dataset & Target Column

# %%
# Expand dataset
schemes_expanded = pd.concat([schemes] * 50, ignore_index=True)

# Synthetic user data
np.random.seed(42)
schemes_expanded["user_age"] = np.random.randint(18, 65, size=len(schemes_expanded))
schemes_expanded["user_income"] = np.random.randint(50000, 600000, size=len(schemes_expanded))

# Eligibility label
schemes_expanded["eligible"] = np.where(
    (schemes_expanded["user_age"] >= schemes_expanded["min_age"]) &
    (schemes_expanded["user_age"] <= schemes_expanded["max_age"]) &
    (schemes_expanded["user_income"] <= schemes_expanded["max_income"]),
    1, 0
)

schemes_expanded["eligible"].value_counts()
# Out:
# eligible
# 0    349
# 1    101
# Name: count, dtype: int64

# %% [markdown]
# # Eligibility Distribution

# %%
plt.figure()
schemes_expanded["eligible"].value_counts().plot(kind="bar")
plt.title("Eligibility Distribution - Schemes")
plt.show()

# %% [markdown]
# # Encode Categorical Columns (Schemes)

# %%
encoder = LabelEncoder()

for col in schemes_expanded.select_dtypes(include="object").columns:
    schemes_expanded[col] = encoder.fit_transform(schemes_expanded[col])

# %% [markdown]
# # Feature & Target Split (Schemes)

# %%
X_sc = schemes_expanded.drop(["eligible", "apply_link"], axis=1)
y_sc = schemes_expanded["eligible"]

# %% [markdown]
# # Train-Test Split (Schemes)

# %%
X_sc_train, X_sc_test, y_sc_train, y_sc_test = train_test_split(
    X_sc, y_sc, test_size=0.25, random_state=42, stratify=y_sc
)

# %% [markdown]
# # Train ML Models

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42)
}

# %% [markdown]
# # Test ML Models

# %%
for name, model in models.items():
    model.fit(X_sc_train, y_sc_train)
    preds = model.predict(X_sc_test)

    print(f"\n{name}")
    print("Accuracy:", accuracy_score(y_sc_test, preds))
    print("Confusion Matrix:\n", confusion_matrix(y_sc_test, preds))
    print("Classification Report:\n", classification_report(y_sc_test, preds))
# Out:
# Logistic Regression
# Accuracy: 0.9557522123893806
# Confusion Matrix:
#  [[85  3]
#  [ 2 23]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.97      0.97        88
#            1       0.88      0.92      0.90        25
#
#     accuracy                           0.96       113
#    macro avg       0.93      0.94      0.94       113
# weighted avg       0.96      0.96      0.96       113
#
#
# Decision Tree
# Accuracy: 0.9734513274336283
# Confusion Matrix:
#  [[86  2]
#  [ 1 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98        88
#            1       0.92      0.96      0.94        25
#
#     accuracy                           0.97       113
#    macro avg       0.96      0.97      0.96       113
# weighted avg       0.97      0.97      0.97       113
#
#
# Random Forest
# Accuracy: 0.9823008849557522
# Confusion Matrix:
#  [[87  1]
#  [ 1 24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        88
#            1       0.96      0.96      0.96        25
#
#     accuracy                           0.98       113
#    macro avg       0.97      0.97      0.97       113
# weighted avg       0.98      0.98      0.98       113
# c:\Users\prava\anaconda3\envs\benefitbot\lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # AP Scholarships

# %% [markdown]
# # Expand Scholarships Dataset & Create Target

# %%
scholarships_expanded = pd.concat([scholarships] * 50, ignore_index=True)

# Synthetic user income & marks
np.random.seed(42)
scholarships_expanded["user_income"] = np.random.randint(50000, 800000, size=len(scholarships_expanded))
scholarships_expanded["user_marks"] = np.random.randint(35, 100, size=len(scholarships_expanded))

# Eligibility label
scholarships_expanded["eligible"] = np.where(
    (scholarships_expanded["user_marks"] >= scholarships_expanded["min_marks"]) &
    (scholarships_expanded["user_income"] <= scholarships_expanded["max_income"]),
    1, 0
)

scholarships_expanded["eligible"].value_counts()
# Out:
# eligible
# 0    256
# 1     94
# Name: count, dtype: int64

# %% [markdown]
# # Eligibility Distribution (Scholarships)

# %%
plt.figure()
scholarships_expanded["eligible"].value_counts().plot(kind="bar")
plt.title("Eligibility Distribution - Scholarships")
plt.show()

# %% [markdown]
# # Encode Categorical Columns (Scholarships)

# %%
for col in scholarships_expanded.select_dtypes(include="object").columns:
    scholarships_expanded[col] = encoder.fit_transform(scholarships_expanded[col])

# %% [markdown]
# # Feature & Target Split (Scholarships)

# %%
X_sch = scholarships_expanded.drop(["eligible", "apply_link"], axis=1)
y_sch = scholarships_expanded["eligible"]

# %% [markdown]
# # Train-Test Split (Scholarships)

# %%
X_sch_train, X_sch_test, y_sch_train, y_sch_test = train_test_split(
    X_sch, y_sch, test_size=0.25, random_state=42, stratify=y_sch
)

# %% [markdown]
# # Train & Test ML Models

# %%
print("🎓 AP SCHOLARSHIPS MODEL RESULTS")

for name, model in models.items():
    model.fit(X_sch_train, y_sch_train)
    preds = model.predict(X_sch_test)

    print(f"\n{name}")
    print("Accuracy:", accuracy_score(y_sch_test, preds))
    print("Confusion Matrix:\n", confusion_matrix(y_sch_test, preds))
    print("Classification Report:\n", classification_report(y_sch_test, preds))
# Out:
# 🎓 AP SCHOLARSHIPS MODEL RESULTS
#
# Logistic Regression
# Accuracy: 0.7954545454545454
# Confusion Matrix:
#  [[55  9]
#  [ 9 15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86        64
#            1       0.62      0.62      0.62        24
#
#     accuracy                           0.80        88
#    macro avg       0.74      0.74      0.74        88
# weighted avg       0.80      0.80      0.80        88
#
#
# Decision Tree
# Accuracy: 0.9431818181818182
# Confusion Matrix:
#  [[63  1]
#  [ 4 20]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96        64
#            1       0.95      0.83      0.89        24
#
#     accuracy                           0.94        88
#    macro avg       0.95      0.91      0.93        88
# weighted avg       0.94      0.94      0.94        88
#
#
# Random Forest
# Accuracy: 0.9431818181818182
# Confusion Matrix:
#  [[64  0]
#  [ 5 19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96        64
#            1       1.00      0.79      0.88        24
#
#     accuracy                           0.94        88
#    macro avg       0.96      0.90      0.92        88
# weighted avg       0.95      0.94      0.94        88

# %% [markdown]
# # Train Final Best Model (Schemes)

# %%
best_scheme_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

best_scheme_model.fit(X_sc, y_sc)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # Train Final Best Model (Scholarships)

# %%
best_scholarship_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

best_scholarship_model.fit(X_sch, y_sch)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # Saving the Models

# %%
import joblib

joblib.dump(best_scheme_model, "best_scheme_model.pkl")
joblib.dump(best_scholarship_model, "best_scholarship_model.pkl")

print("Models saved successfully!")
# Out:
# Models saved successfully!

# %% [markdown]
# # Save Model Parameters & Feature Names

# %%
# Save parameters
scheme_model_params = {
    "model_type": "RandomForestClassifier",
    "parameters": best_scheme_model.get_params(),
    "features": list(X_sc.columns)
}

scholarship_model_params = {
    "model_type": "RandomForestClassifier",
    "parameters": best_scholarship_model.get_params(),
    "features": list(X_sch.columns)
}

joblib.dump(scheme_model_params, "scheme_model_params.pkl")
joblib.dump(scholarship_model_params, "scholarship_model_params.pkl")

print("Model parameters saved!")
# Out:
# Model parameters saved!

# %% [markdown]
# # Load and Test Saved Model

# %%
# Load models
loaded_scheme_model = joblib.load("best_scheme_model.pkl")
loaded_scholarship_model = joblib.load("best_scholarship_model.pkl")

# Test with one sample
sample_scheme = X_sc.iloc[[0]]
sample_scholarship = X_sch.iloc[[0]]

print("Scheme Prediction:", loaded_scheme_model.predict(sample_scheme))
print("Scholarship Prediction:", loaded_scholarship_model.predict(sample_scholarship))
# Out:
# Scheme Prediction: [0]
# Scholarship Prediction: [0]
